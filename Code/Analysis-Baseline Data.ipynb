# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pickle

from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, f1_score, recall_score, mean_squared_error, roc_curve, auc
from sklearn.feature_selection import SelectFromModel, GenericUnivariateSelect
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression, LinearRegression, HuberRegressor, Lasso
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBClassifier

# %%
df_feats = pd.read_csv('df_feats_baselines.csv')
df_targets = pd.read_csv('df_targets_baselines.csv')

# %% [markdown]
# ### Helper functions

# %%
def _color_red_or_green(val):
    color = 'green' if val > 0.75 else ('orange' if val > 0.65 else ('red' if val < 0.65 else 'black'))
    return 'color: %s' % color

# %%
def coefs_to_df(X, model, features_selected, scaler, dict_name, K_all, fs_method=None):
    """
    This function extracts the feature coefficients of a model and saves it in to a dataframe
    """ 
    
    tree_models = ['RandomForestRegressor', 'RandomForestClassifier', 'XGBClassifier']
    
    
    if model.__class__.__name__ in tree_models:
        
        coefs = model.feature_importances_
        
    else:
        
        coefs = model.coef_
     

    if fs_method == 'PCA':
        
        pca_coefs = features_selected.components_.T * coefs
        
        all_coefs = pca_coefs.sum(axis=1)

    else:
       
        coefs_vals = coefs.flatten().tolist()
    
        # getting indexes of remaining features' coefficients
        coefs_inds = [i for i, element in enumerate(features_selected.get_support()) if element == True]

        all_coefs = [coefs_vals[coefs_inds.index(i)] if i in coefs_inds else 0 for i in range(len(X.columns))]
        

    all_coefs_df = pd.DataFrame([all_coefs], columns=X.columns)
    all_coefs_df['Model'] = model.__class__.__name__
    all_coefs_df['Scaler'] = scaler.__class__.__name__
    all_coefs_df['Feat Selection'] = dict_name
    all_coefs_df['Type'] = 'All_data'
    all_coefs_df['Num of Features'] = K_all
    
    all_coefs_df.set_index(['Model', 'Scaler', 'Feat Selection', 'Type', 'Num of Features'], inplace=True)
    
    return all_coefs_df

# %%
def get_classification_metrics(clf, X, y):

    clf.fit(X, y)
    y_pred = clf.predict(X)

    accuracy_all = accuracy_score(y, y_pred)
    f1_all = f1_score(y, y_pred, average='weighted')
    sensitivity_all = recall_score(y, y_pred, average='weighted')
    specificity_all = recall_score(y, y_pred, labels=[0], average='weighted')
    fpr, tpr, thresholds = roc_curve(y, y_pred, pos_label=1)
    auc_all = auc(fpr, tpr)

    return [accuracy_all, f1_all, sensitivity_all, specificity_all, auc_all]

# %% [markdown]
# ## Classifiers
#
# target - cesdclinmA (Depression - yes/no)

# %%
start_total_runtime = time.time()

# Dependent and independent variables

X = df_feats.drop(columns = ['study_id'])
y = df_targets['cesdclinmA'].astype(int)

# Models
models = [LogisticRegression(max_iter=3000, solver='liblinear'),
         RandomForestClassifier(max_depth=5, min_samples_split=4, n_estimators = 200, min_samples_leaf=3),
         XGBClassifier(use_label_encoder=False, eval_metric='error', eta=1, max_depth=4)]

# Scalers
scalers = [StandardScaler(), RobustScaler()]

# Feature selections methods
selectors = [PCA(), GenericUnivariateSelect(mode='fpr', param=0.5), Lasso(alpha=0.15, max_iter=5000, tol=0.2)]

# list of results per model
final_results = []

# Dataframe saving each model's coefficients
coefs_df_clfs = pd.DataFrame()

# Cross-Validation object
skf = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)

max_val_accuracy = 0

# Testing each of the models
for model in models:
    
    # Testing each of the scalers
    for scaler in scalers:
                
            all_scores = {'PCA': {'Accuracy_All_X': [], 'F1_All_X': [], 'Sensitivity_All_X': [], 
                          'Specificity_All_X': [], 'AUC_All_X': [], 'K_All_X': [],
                          'Train_Accuracy_CV': [], 'Val_Accuracy_CV': [], 'Train_F1_CV': [], 'Val_F1_CV': [], 
                          'Val_Sensitivity_CV': [], 'Val_Specificity_CV': [], 'Val_AUC_CV': [], 'K': []}, 
                          
                         'FPR': {'Accuracy_All_X': [], 'F1_All_X': [], 'Sensitivity_All_X': [], 
                          'Specificity_All_X': [], 'AUC_All_X': [], 'K_All_X': [],
                         'Train_Accuracy_CV': [], 'Val_Accuracy_CV': [], 'Train_F1_CV': [], 'Val_F1_CV': [], 
                          'Val_Sensitivity_CV': [], 'Val_Specificity_CV': [], 'Val_AUC_CV': [], 'K': []}, 
                          
                        'Lasso': {'Accuracy_All_X': [], 'F1_All_X': [], 'Sensitivity_All_X': [], 
                        'Specificity_All_X': [], 'AUC_All_X': [], 'K_All_X': [],
                        'Train_Accuracy_CV': [], 'Val_Accuracy_CV': [], 'Train_F1_CV': [], 'Val_F1_CV': [], 
                        'Val_Sensitivity_CV': [], 'Val_Specificity_CV': [], 'Val_AUC_CV': [], 'K': []}}
                
            # cross-validating
            
            for ind, (train_index, val_index) in enumerate(skf.split(X, y)):
                
                X_train, X_val = X.iloc[train_index], X.iloc[val_index]
                y_train, y_val = y.iloc[train_index], y.iloc[val_index]
                
                # Normalizing
                
                scaler.fit(X_train)
                X_train = scaler.transform(X_train)
                X_val = scaler.transform(X_val)
                
                # Testing each of the feature selection methods
                
                for feat_selector in selectors:
                    
                    # Creating new X-sets for each iteration
                    X_train_fresh = X_train
                    X_val_fresh = X_val
                    
                    dict_name = feat_selector.__class__.__name__
                    
                    if dict_name == 'PCA':
            
                        fs = feat_selector.fit(X_train_fresh)
                        array = np.cumsum(fs.explained_variance_ratio_)
                        
                        # Selecting number of principal components
                        
                        K = np.argmax(array > 0.8)
                        fs = PCA(n_components=K).fit(X_train_fresh)
                        
                        if ind == 0:
                            
                            # Calculating metrics on all X Data
                            
                            X = df_feats.drop(columns = ['study_id'])
                            y = df_targets['cesdclinmA'].astype(int)
                            scaler.fit(X)
                            X = pd.DataFrame(scaler.transform(X), columns=X.columns)
                            
                            pca = PCA()
                            fs_all_pca = pca.fit(X)
                            array_all = np.cumsum(fs_all_pca.explained_variance_ratio_)
                            
                            # Selecting number of principal components
                            
                            K_all = np.argmax(array_all > 0.9)

                            fs_all_pca = PCA(n_components=K_all).fit(X)
                            
                            X_all_pca = fs_all_pca.transform(X)
                            
                            clf_all_pca = model
                            
                            metrics_all = get_classification_metrics(clf_all_pca, X_all_pca, y)
                            
                            # Getting coefficients of all features
                            
                            all_coefs_df_pca = coefs_to_df(X, clf_all_pca, fs_all_pca, scaler, dict_name, K_all, 'PCA')
                            
                            coefs_df_clfs = pd.concat([coefs_df_clfs, all_coefs_df_pca], axis=0)
        

                    elif dict_name == 'Lasso':               

                        fs = SelectFromModel(feat_selector)
                        fs.fit(X_train_fresh, y_train)
                        K = sum(fs.get_support())
                        
                        if ind == 0:
                            
                            # Calculating metrics on all X Data
                           
                            fs_all_lasso = SelectFromModel(feat_selector)
                            fs_all_lasso.fit(X, y)
                            X_all_lasso = fs_all_lasso.transform(X)
                            
                            clf_all_lasso = model
                            
                            metrics_all = get_classification_metrics(clf_all_lasso, X_all_lasso, y)
                            
                            K_all = sum(fs_all_lasso.get_support())
                            
                            
                            
                            # Getting coefficients of all features
                            
                            all_coefs_df_lasso = coefs_to_df(X, clf_all_lasso, fs_all_lasso, scaler, dict_name, K_all)
                            
                            coefs_df_clfs = pd.concat([coefs_df_clfs, all_coefs_df_lasso], axis=0)
                        
                    else:
                        
                        dict_name = 'FPR'
                        fs = feat_selector.fit(X_train_fresh, y_train)
                        
                        K = sum(fs.get_support())
                        
                        if ind == 0:
                            
                            # Calculating metrics on all X Data
                            
                            fs_all_fpr = feat_selector.fit(X, y)
                            X_all_fpr = fs_all_fpr.transform(X)
                            
                            clf_all_fpr = model
                            
                            metrics_all = get_classification_metrics(clf_all_fpr, X_all_fpr, y)
                            
                            K_all = sum(fs_all_fpr.get_support())
                            
                            # Getting coefficients of all features
                            
                            all_coefs_df_fpr = coefs_to_df(X, clf_all_fpr, fs_all_fpr, scaler, dict_name, K_all)
                            
                            coefs_df_clfs = pd.concat([coefs_df_clfs, all_coefs_df_fpr], axis=0)
                                        
                    X_train_fresh = fs.transform(X_train_fresh)
                    X_val_fresh = fs.transform(X_val_fresh)
                    
                    # Training, predicting and evaluating each model
                    
                    clf = model
          
                    clf.fit(X_train_fresh, y_train)
                    y_pred_train = clf.predict(X_train_fresh)
                    y_pred_val = clf.predict(X_val_fresh)
                    
                    # appending metrics of all data to all_scores dictionary
                    if ind == 0:
                        for i, key in enumerate(all_scores[dict_name]):
                            if i == 5:
                                break
                            all_scores[dict_name][key].append(metrics_all[i])
                        all_scores[dict_name]['K_All_X'].append(K_all)
                    
                    # appending metrics of specific fold
                    all_scores[dict_name]['Train_Accuracy_CV'].append(accuracy_score(y_train, y_pred_train))
                    all_scores[dict_name]['Train_F1_CV'].append(f1_score(y_train, y_pred_train, average='weighted'))
                    
                    all_scores[dict_name]['Val_Accuracy_CV'].append(accuracy_score(y_val, y_pred_val))
                    all_scores[dict_name]['Val_F1_CV'].append(f1_score(y_val, y_pred_val, average='weighted'))
                    all_scores[dict_name]['Val_Sensitivity_CV'].append(recall_score(y_val, y_pred_val, average='weighted'))
                    all_scores[dict_name]['Val_Specificity_CV'].append(recall_score(y_val, y_pred_val, labels = [0], average='weighted'))
                    fpr, tpr, thresholds = roc_curve(y_val, y_pred_val, pos_label=1)
                    all_scores[dict_name]['Val_AUC_CV'].append(auc(fpr, tpr))

                    all_scores[dict_name]['K'].append(K)
                    

                            
                        
            # Averaging CV results of splits
            for dct, v in all_scores.items():
                for metric, score in v.items():
                        v[metric] = np.mean(score)
            
            
            dicts_keys = ['PCA', 'FPR', 'Lasso']
            
            for dct in dicts_keys:
                final_results.append({'Model': clf.__class__.__name__, 'scaler': scaler.__class__.__name__, 
                                      'Feat Selection': dct,
                                      'Type': 'CV',
                                      'Num of Features': round(all_scores[dct]['K']),
                                      'Train_Accuracy_CV': all_scores[dct]['Train_Accuracy_CV'], 
                                      'Val_Accuracy_CV': all_scores[dct]['Val_Accuracy_CV'], 
                                      'Train_F1_CV': all_scores[dct]['Train_F1_CV'], 
                                      'Val_F1_CV': all_scores[dct]['Val_F1_CV'], 
                                      'Val_Sensitivity_CV': all_scores[dct]['Val_Sensitivity_CV'], 
                                      'Val_Specificity_CV': all_scores[dct]['Val_Specificity_CV'], 
                                      'Val_AUC_CV': all_scores[dct]['Val_AUC_CV']})
                final_results.append({'Model': clf.__class__.__name__, 'scaler': scaler.__class__.__name__, 
                                      'Feat Selection': dct,
                                      'Type': 'All_data',
                                      'Num of Features': int(all_scores[dct]['K_All_X']),
                                      'Accuracy_All_X': all_scores[dct]['Accuracy_All_X'],
                                      'F1_All_X': all_scores[dct]['F1_All_X'],
                                      'Sensitivity_All_X': all_scores[dct]['Sensitivity_All_X'],
                                      'Specificity_All_X': all_scores[dct]['Specificity_All_X'],
                                      'AUC_All_X': all_scores[dct]['AUC_All_X']})  
                
# normalizing coefficients
coefs_df_clfs = coefs_df_clfs.abs()
coefs_df_clfs = (coefs_df_clfs.T / coefs_df_clfs.T.sum()).T
                    
final_results_df = pd.DataFrame(final_results).set_index(['Model', 'scaler', 'Feat Selection', 'Type'])  

end_total_runtime = time.time()

print(f'Total runtime: {round(end_total_runtime - start_total_runtime,5)} seconds')

final_results_df.style.applymap(_color_red_or_green)
# Out:
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# Total runtime: 32.44129 seconds
# <style  type="text/css" >
# #T_b4cf2_row0_col0,#T_b4cf2_row0_col1,#T_b4cf2_row0_col3,#T_b4cf2_row0_col6,#T_b4cf2_row1_col0,#T_b4cf2_row1_col8,#T_b4cf2_row1_col9,#T_b4cf2_row1_col10,#T_b4cf2_row1_col11,#T_b4cf2_row1_col12,#T_b4cf2_row2_col0,#T_b4cf2_row2_col1,#T_b4cf2_row2_col3,#T_b4cf2_row3_col0,#T_b4cf2_row3_col8,#T_b4cf2_row3_col9,#T_b4cf2_row3_col10,#T_b4cf2_row3_col11,#T_b4cf2_row3_col12,#T_b4cf2_row4_col0,#T_b4cf2_row4_col1,#T_b4cf2_row4_col3,#T_b4cf2_row4_col6,#T_b4cf2_row5_col0,#T_b4cf2_row5_col8,#T_b4cf2_row5_col9,#T_b4cf2_row5_col10,#T_b4cf2_row5_col11,#T_b4cf2_row6_col0,#T_b4cf2_row6_col1,#T_b4cf2_row6_col3,#T_b4cf2_row6_col6,#T_b4cf2_row7_col0,#T_b4cf2_row7_col8,#T_b4cf2_row7_col9,#T_b4cf2_row7_col10,#T_b4cf2_row7_col11,#T_b4cf2_row7_col12,#T_b4cf2_row8_col0,#T_b4cf2_row8_col1,#T_b4cf2_row8_col3,#T_b4cf2_row9_col0,#T_b4cf2_row9_col8,#T_b4cf2_row9_col9,#T_b4cf2_row9_col10,#T_b4cf2_row9_col11,#T_b4cf2_row9_col12,#T_b4cf2_row10_col0,#T_b4cf2_row10_col1,#T_b4cf2_row10_col3,#T_b4cf2_row10_col6,#T_b4cf2_row11_col0,#T_b4cf2_row11_col8,#T_b4cf2_row11_col9,#T_b4cf2_row11_col10,#T_b4cf2_row11_col11,#T_b4cf2_row12_col0,#T_b4cf2_row12_col1,#T_b4cf2_row12_col2,#T_b4cf2_row12_col3,#T_b4cf2_row12_col5,#T_b4cf2_row12_col6,#T_b4cf2_row13_col0,#T_b4cf2_row13_col8,#T_b4cf2_row13_col9,#T_b4cf2_row13_col10,#T_b4cf2_row13_col11,#T_b4cf2_row13_col12,#T_b4cf2_row14_col0,#T_b4cf2_row14_col1,#T_b4cf2_row14_col2,#T_b4cf2_row14_col3,#T_b4cf2_row14_col5,#T_b4cf2_row14_col6,#T_b4cf2_row15_col0,#T_b4cf2_row15_col8,#T_b4cf2_row15_col9,#T_b4cf2_row15_col10,#T_b4cf2_row15_col11,#T_b4cf2_row15_col12,#T_b4cf2_row16_col0,#T_b4cf2_row16_col1,#T_b4cf2_row16_col3,#T_b4cf2_row16_col6,#T_b4cf2_row17_col0,#T_b4cf2_row17_col8,#T_b4cf2_row17_col9,#T_b4cf2_row17_col10,#T_b4cf2_row17_col11,#T_b4cf2_row18_col0,#T_b4cf2_row18_col1,#T_b4cf2_row18_col2,#T_b4cf2_row18_col3,#T_b4cf2_row18_col5,#T_b4cf2_row18_col6,#T_b4cf2_row19_col0,#T_b4cf2_row19_col8,#T_b4cf2_row19_col9,#T_b4cf2_row19_col10,#T_b4cf2_row19_col11,#T_b4cf2_row20_col0,#T_b4cf2_row20_col1,#T_b4cf2_row20_col2,#T_b4cf2_row20_col3,#T_b4cf2_row20_col5,#T_b4cf2_row20_col6,#T_b4cf2_row21_col0,#T_b4cf2_row21_col8,#T_b4cf2_row21_col9,#T_b4cf2_row21_col10,#T_b4cf2_row21_col11,#T_b4cf2_row22_col0,#T_b4cf2_row22_col1,#T_b4cf2_row22_col3,#T_b4cf2_row22_col6,#T_b4cf2_row23_col0,#T_b4cf2_row23_col8,#T_b4cf2_row23_col9,#T_b4cf2_row23_col10,#T_b4cf2_row23_col11,#T_b4cf2_row24_col0,#T_b4cf2_row24_col1,#T_b4cf2_row24_col3,#T_b4cf2_row24_col6,#T_b4cf2_row25_col0,#T_b4cf2_row25_col8,#T_b4cf2_row25_col9,#T_b4cf2_row25_col10,#T_b4cf2_row25_col11,#T_b4cf2_row25_col12,#T_b4cf2_row26_col0,#T_b4cf2_row26_col1,#T_b4cf2_row26_col3,#T_b4cf2_row26_col6,#T_b4cf2_row27_col0,#T_b4cf2_row27_col8,#T_b4cf2_row27_col9,#T_b4cf2_row27_col10,#T_b4cf2_row27_col11,#T_b4cf2_row27_col12,#T_b4cf2_row28_col0,#T_b4cf2_row28_col1,#T_b4cf2_row28_col3,#T_b4cf2_row28_col6,#T_b4cf2_row29_col0,#T_b4cf2_row29_col8,#T_b4cf2_row29_col9,#T_b4cf2_row29_col10,#T_b4cf2_row29_col11,#T_b4cf2_row30_col0,#T_b4cf2_row30_col1,#T_b4cf2_row30_col3,#T_b4cf2_row30_col6,#T_b4cf2_row31_col0,#T_b4cf2_row31_col8,#T_b4cf2_row31_col9,#T_b4cf2_row31_col10,#T_b4cf2_row31_col11,#T_b4cf2_row31_col12,#T_b4cf2_row32_col0,#T_b4cf2_row32_col1,#T_b4cf2_row32_col3,#T_b4cf2_row32_col6,#T_b4cf2_row33_col0,#T_b4cf2_row33_col8,#T_b4cf2_row33_col9,#T_b4cf2_row33_col10,#T_b4cf2_row33_col11,#T_b4cf2_row33_col12,#T_b4cf2_row34_col0,#T_b4cf2_row34_col1,#T_b4cf2_row34_col3,#T_b4cf2_row34_col6,#T_b4cf2_row35_col0,#T_b4cf2_row35_col8,#T_b4cf2_row35_col9,#T_b4cf2_row35_col10,#T_b4cf2_row35_col11,#T_b4cf2_row35_col12{
#             color:  green;
#         }#T_b4cf2_row0_col2,#T_b4cf2_row0_col4,#T_b4cf2_row0_col5,#T_b4cf2_row2_col2,#T_b4cf2_row2_col4,#T_b4cf2_row2_col5,#T_b4cf2_row2_col6,#T_b4cf2_row4_col2,#T_b4cf2_row4_col4,#T_b4cf2_row4_col5,#T_b4cf2_row6_col2,#T_b4cf2_row6_col4,#T_b4cf2_row6_col5,#T_b4cf2_row8_col2,#T_b4cf2_row8_col5,#T_b4cf2_row8_col6,#T_b4cf2_row10_col2,#T_b4cf2_row10_col4,#T_b4cf2_row10_col5,#T_b4cf2_row11_col12,#T_b4cf2_row12_col4,#T_b4cf2_row14_col4,#T_b4cf2_row16_col2,#T_b4cf2_row16_col4,#T_b4cf2_row16_col5,#T_b4cf2_row18_col4,#T_b4cf2_row19_col12,#T_b4cf2_row20_col4,#T_b4cf2_row21_col12,#T_b4cf2_row22_col2,#T_b4cf2_row22_col4,#T_b4cf2_row22_col5,#T_b4cf2_row23_col12,#T_b4cf2_row24_col2,#T_b4cf2_row24_col4,#T_b4cf2_row24_col5,#T_b4cf2_row26_col2,#T_b4cf2_row26_col5,#T_b4cf2_row28_col2,#T_b4cf2_row28_col4,#T_b4cf2_row28_col5,#T_b4cf2_row29_col12,#T_b4cf2_row30_col2,#T_b4cf2_row30_col5,#T_b4cf2_row32_col2,#T_b4cf2_row32_col5,#T_b4cf2_row34_col2,#T_b4cf2_row34_col4,#T_b4cf2_row34_col5{
#             color:  orange;
#         }#T_b4cf2_row0_col7,#T_b4cf2_row2_col7,#T_b4cf2_row4_col7,#T_b4cf2_row5_col12,#T_b4cf2_row6_col7,#T_b4cf2_row8_col4,#T_b4cf2_row8_col7,#T_b4cf2_row10_col7,#T_b4cf2_row12_col7,#T_b4cf2_row14_col7,#T_b4cf2_row16_col7,#T_b4cf2_row17_col12,#T_b4cf2_row18_col7,#T_b4cf2_row20_col7,#T_b4cf2_row22_col7,#T_b4cf2_row24_col7,#T_b4cf2_row26_col4,#T_b4cf2_row26_col7,#T_b4cf2_row28_col7,#T_b4cf2_row30_col4,#T_b4cf2_row30_col7,#T_b4cf2_row32_col4,#T_b4cf2_row32_col7,#T_b4cf2_row34_col7{
#             color:  red;
#         }#T_b4cf2_row0_col8,#T_b4cf2_row0_col9,#T_b4cf2_row0_col10,#T_b4cf2_row0_col11,#T_b4cf2_row0_col12,#T_b4cf2_row1_col1,#T_b4cf2_row1_col2,#T_b4cf2_row1_col3,#T_b4cf2_row1_col4,#T_b4cf2_row1_col5,#T_b4cf2_row1_col6,#T_b4cf2_row1_col7,#T_b4cf2_row2_col8,#T_b4cf2_row2_col9,#T_b4cf2_row2_col10,#T_b4cf2_row2_col11,#T_b4cf2_row2_col12,#T_b4cf2_row3_col1,#T_b4cf2_row3_col2,#T_b4cf2_row3_col3,#T_b4cf2_row3_col4,#T_b4cf2_row3_col5,#T_b4cf2_row3_col6,#T_b4cf2_row3_col7,#T_b4cf2_row4_col8,#T_b4cf2_row4_col9,#T_b4cf2_row4_col10,#T_b4cf2_row4_col11,#T_b4cf2_row4_col12,#T_b4cf2_row5_col1,#T_b4cf2_row5_col2,#T_b4cf2_row5_col3,#T_b4cf2_row5_col4,#T_b4cf2_row5_col5,#T_b4cf2_row5_col6,#T_b4cf2_row5_col7,#T_b4cf2_row6_col8,#T_b4cf2_row6_col9,#T_b4cf2_row6_col10,#T_b4cf2_row6_col11,#T_b4cf2_row6_col12,#T_b4cf2_row7_col1,#T_b4cf2_row7_col2,#T_b4cf2_row7_col3,#T_b4cf2_row7_col4,#T_b4cf2_row7_col5,#T_b4cf2_row7_col6,#T_b4cf2_row7_col7,#T_b4cf2_row8_col8,#T_b4cf2_row8_col9,#T_b4cf2_row8_col10,#T_b4cf2_row8_col11,#T_b4cf2_row8_col12,#T_b4cf2_row9_col1,#T_b4cf2_row9_col2,#T_b4cf2_row9_col3,#T_b4cf2_row9_col4,#T_b4cf2_row9_col5,#T_b4cf2_row9_col6,#T_b4cf2_row9_col7,#T_b4cf2_row10_col8,#T_b4cf2_row10_col9,#T_b4cf2_row10_col10,#T_b4cf2_row10_col11,#T_b4cf2_row10_col12,#T_b4cf2_row11_col1,#T_b4cf2_row11_col2,#T_b4cf2_row11_col3,#T_b4cf2_row11_col4,#T_b4cf2_row11_col5,#T_b4cf2_row11_col6,#T_b4cf2_row11_col7,#T_b4cf2_row12_col8,#T_b4cf2_row12_col9,#T_b4cf2_row12_col10,#T_b4cf2_row12_col11,#T_b4cf2_row12_col12,#T_b4cf2_row13_col1,#T_b4cf2_row13_col2,#T_b4cf2_row13_col3,#T_b4cf2_row13_col4,#T_b4cf2_row13_col5,#T_b4cf2_row13_col6,#T_b4cf2_row13_col7,#T_b4cf2_row14_col8,#T_b4cf2_row14_col9,#T_b4cf2_row14_col10,#T_b4cf2_row14_col11,#T_b4cf2_row14_col12,#T_b4cf2_row15_col1,#T_b4cf2_row15_col2,#T_b4cf2_row15_col3,#T_b4cf2_row15_col4,#T_b4cf2_row15_col5,#T_b4cf2_row15_col6,#T_b4cf2_row15_col7,#T_b4cf2_row16_col8,#T_b4cf2_row16_col9,#T_b4cf2_row16_col10,#T_b4cf2_row16_col11,#T_b4cf2_row16_col12,#T_b4cf2_row17_col1,#T_b4cf2_row17_col2,#T_b4cf2_row17_col3,#T_b4cf2_row17_col4,#T_b4cf2_row17_col5,#T_b4cf2_row17_col6,#T_b4cf2_row17_col7,#T_b4cf2_row18_col8,#T_b4cf2_row18_col9,#T_b4cf2_row18_col10,#T_b4cf2_row18_col11,#T_b4cf2_row18_col12,#T_b4cf2_row19_col1,#T_b4cf2_row19_col2,#T_b4cf2_row19_col3,#T_b4cf2_row19_col4,#T_b4cf2_row19_col5,#T_b4cf2_row19_col6,#T_b4cf2_row19_col7,#T_b4cf2_row20_col8,#T_b4cf2_row20_col9,#T_b4cf2_row20_col10,#T_b4cf2_row20_col11,#T_b4cf2_row20_col12,#T_b4cf2_row21_col1,#T_b4cf2_row21_col2,#T_b4cf2_row21_col3,#T_b4cf2_row21_col4,#T_b4cf2_row21_col5,#T_b4cf2_row21_col6,#T_b4cf2_row21_col7,#T_b4cf2_row22_col8,#T_b4cf2_row22_col9,#T_b4cf2_row22_col10,#T_b4cf2_row22_col11,#T_b4cf2_row22_col12,#T_b4cf2_row23_col1,#T_b4cf2_row23_col2,#T_b4cf2_row23_col3,#T_b4cf2_row23_col4,#T_b4cf2_row23_col5,#T_b4cf2_row23_col6,#T_b

# %%
final_results_df.sort_values(by=['Val_Accuracy_CV'], ascending=False)[0:8].style.applymap(_color_red_or_green)
# Out:
# <style  type="text/css" >
# #T_19460_row0_col0,#T_19460_row0_col1,#T_19460_row0_col2,#T_19460_row0_col3,#T_19460_row0_col5,#T_19460_row0_col6,#T_19460_row1_col0,#T_19460_row1_col1,#T_19460_row1_col2,#T_19460_row1_col3,#T_19460_row1_col5,#T_19460_row1_col6,#T_19460_row2_col0,#T_19460_row2_col1,#T_19460_row2_col2,#T_19460_row2_col3,#T_19460_row2_col5,#T_19460_row2_col6,#T_19460_row3_col0,#T_19460_row3_col1,#T_19460_row3_col2,#T_19460_row3_col3,#T_19460_row3_col5,#T_19460_row3_col6,#T_19460_row4_col0,#T_19460_row4_col1,#T_19460_row4_col3,#T_19460_row4_col6,#T_19460_row5_col0,#T_19460_row5_col1,#T_19460_row5_col3,#T_19460_row5_col6,#T_19460_row6_col0,#T_19460_row6_col1,#T_19460_row6_col3,#T_19460_row6_col6,#T_19460_row7_col0,#T_19460_row7_col1,#T_19460_row7_col3,#T_19460_row7_col6{
#             color:  green;
#         }#T_19460_row0_col4,#T_19460_row1_col4,#T_19460_row2_col4,#T_19460_row3_col4,#T_19460_row4_col2,#T_19460_row4_col4,#T_19460_row4_col5,#T_19460_row5_col2,#T_19460_row5_col4,#T_19460_row5_col5,#T_19460_row6_col2,#T_19460_row6_col4,#T_19460_row6_col5,#T_19460_row7_col2,#T_19460_row7_col4,#T_19460_row7_col5{
#             color:  orange;
#         }#T_19460_row0_col7,#T_19460_row1_col7,#T_19460_row2_col7,#T_19460_row3_col7,#T_19460_row4_col7,#T_19460_row5_col7,#T_19460_row6_col7,#T_19460_row7_col7{
#             color:  red;
#         }#T_19460_row0_col8,#T_19460_row0_col9,#T_19460_row0_col10,#T_19460_row0_col11,#T_19460_row0_col12,#T_19460_row1_col8,#T_19460_row1_col9,#T_19460_row1_col10,#T_19460_row1_col11,#T_19460_row1_col12,#T_19460_row2_col8,#T_19460_row2_col9,#T_19460_row2_col10,#T_19460_row2_col11,#T_19460_row2_col12,#T_19460_row3_col8,#T_19460_row3_col9,#T_19460_row3_col10,#T_19460_row3_col11,#T_19460_row3_col12,#T_19460_row4_col8,#T_19460_row4_col9,#T_19460_row4_col10,#T_19460_row4_col11,#T_19460_row4_col12,#T_19460_row5_col8,#T_19460_row5_col9,#T_19460_row5_col10,#T_19460_row5_col11,#T_19460_row5_col12,#T_19460_row6_col8,#T_19460_row6_col9,#T_19460_row6_col10,#T_19460_row6_col11,#T_19460_row6_col12,#T_19460_row7_col8,#T_19460_row7_col9,#T_19460_row7_col10,#T_19460_row7_col11,#T_19460_row7_col12{
#             color:  black;
#         }</style><table id="T_19460_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Num of Features</th>        <th class="col_heading level0 col1" >Train_Accuracy_CV</th>        <th class="col_heading level0 col2" >Val_Accuracy_CV</th>        <th class="col_heading level0 col3" >Train_F1_CV</th>        <th class="col_heading level0 col4" >Val_F1_CV</th>        <th class="col_heading level0 col5" >Val_Sensitivity_CV</th>        <th class="col_heading level0 col6" >Val_Specificity_CV</th>        <th class="col_heading level0 col7" >Val_AUC_CV</th>        <th class="col_heading level0 col8" >Accuracy_All_X</th>        <th class="col_heading level0 col9" >F1_All_X</th>        <th class="col_heading level0 col10" >Sensitivity_All_X</th>        <th class="col_heading level0 col11" >Specificity_All_X</th>        <th class="col_heading level0 col12" >AUC_All_X</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="index_name level1" >scaler</th>        <th class="index_name level2" >Feat Selection</th>        <th class="index_name level3" >Type</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19460_level0_row0" class="row_heading level0 row0" rowspan="5">RandomForestClassifier</th>
#                         <th id="T_19460_level1_row0" class="row_heading level1 row0" >RobustScaler</th>
#                         <th id="T_19460_level2_row0" class="row_heading level2 row0" >PCA</th>
#                         <th id="T_19460_level3_row0" class="row_heading level3 row0" >CV</th>
#                         <td id="T_19460_row0_col0" class="data row0 col0" >11</td>
#                         <td id="T_19460_row0_col1" class="data row0 col1" >0.896069</td>
#                         <td id="T_19460_row0_col2" class="data row0 col2" >0.785000</td>
#                         <td id="T_19460_row0_col3" class="data row0 col3" >0.880623</td>
#                         <td id="T_19460_row0_col4" class="data row0 col4" >0.690635</td>
#                         <td id="T_19460_row0_col5" class="data row0 col5" >0.785000</td>
#                         <td id="T_19460_row0_col6" class="data row0 col6" >1.000000</td>
#                         <td id="T_19460_row0_col7" class="data row0 col7" >0.500000</td>
#                         <td id="T_19460_row0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_19460_row0_col9" class="data row0 col9" >nan</td>
#                         <td id="T_19460_row0_col10" class="data row0 col10" >nan</td>
#                         <td id="T_19460_row0_col11" class="data row0 col11" >nan</td>
#                         <td id="T_19460_row0_col12" class="data row0 col12" >nan</td>
#             </tr>
#             <tr>
#                                 <th id="T_19460_level1_row1" class="row_heading level1 row1" >StandardScaler</th>
#                         <th id="T_19460_level2_row1" class="row_heading level2 row1" >PCA</th>
#                         <th id="T_19460_level3_row1" class="row_heading level3 row1" >CV</th>
#                         <td id="T_19460_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_19460_row1_col1" class="data row1 col1" >0.891251</td>
#                         <td id="T_19460_row1_col2" class="data row1 col2" >0.785000</td>
#                         <td id="T_19460_row1_col3" class="data row1 col3" >0.873092</td>
#                         <td id="T_19460_row1_col4" class="data row1 col4" >0.690635</td>
#                         <td id="T_19460_row1_col5" class="data row1 col5" >0.785000</td>
#                         <td id="T_19460_row1_col6" class="data row1 col6" >1.000000</td>
#                         <td id="T_19460_row1_col7" class="data row1 col7" >0.500000</td>
#                         <td id="T_19460_row1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_19460_row1_col9" class="data row1 col9" >nan</td>
#                         <td id="T_19460_row1_col10" class="data row1 col10" >nan</td>
#                         <td id="T_19460_row1_col11" class="data row1 col11" >nan</td>
#                         <td id="T_19460_row1_col12" class="data row1 col12" >nan</td>
#             </tr>
#             <tr>
#                                 <th id="T_19460_level1_row2" class="row_heading level1 row2" >RobustScaler</th>
#                         <th id="T_19460_level2_row2" class="row_heading level2 row2" >FPR</th>
#                         <th id="T_19460_level3_row2" class="row_heading level3 row2" >CV</th>
#                         <td id="T_19460_row2_col0" class="data row2 col0" >78</td>
#                         <td id="T_19460_row2_col1" class="data row2 col1" >0.924419</td>
#                         <td id="T_19460_row2_col2" class="data row2 col2" >0.780000</td>
#                         <td id="T_19460_row2_col3" class="data row2 col3" >0.916614</td>
#                         <td id="T_19460_row2_col4" class="data row2 col4" >0.705238</td>
#                         <td id="T_19460_row2_col5" class="data row2 col5" >0.780000</td>
#                         <td id="T_19460_row2_col6" class="data row2 col6" >0.966667</td>
#                         <td id="T_19460_row2_col7" class="data row2 col7" >0.533333</td>
#                         <td id="T_19460_row2_col8" class="data row2 co

# %% [markdown]
# ### Top Features vs models Heatmap:

# %%
fig, ax = plt.subplots(figsize=(18, 14))

top_coefs = coefs_df_clfs.loc[coefs_df_clfs.max(axis=1) > 0.05, coefs_df_clfs.max(axis=0) > 0.05]

top_coefs[(top_coefs < 0.01) & (top_coefs > 0) | (top_coefs > -0.01) & (top_coefs < 0)] = 0

sns.heatmap(top_coefs, robust=True, annot=True, cmap="Blues")
plt.savefig('heatmap_cl_baseline_data.png',bbox_inches="tight")
ax.set_xticklabels(top_coefs.columns, rotation=45)
plt.show()

# %% [markdown]
# #### Exporting to csv:

# %%
final_results_df.to_csv('Baseline_Classifiers_Results(baseline_data).csv')
coefs_df_clfs.to_csv('Baseline_Classifiers_Coefficients(baseline_data).csv')

# %% [markdown]
# ## Regressors

# %%
def _color_red_or_green_reg(val):
    color = 'green' if val > 0.75 else ('orange' if val > 0 else ('red' if val < 0 else 'black'))
    return 'color: %s' % color

# %%
def get_regression_metrics(regressor, X, y):

    regressor.fit(X, y)

    r2_all = regressor.score(X, y)
    adj_r2_all = 1 - (1 - r2_all) * (len(y) - 1) / (len(y) - X.shape[1] - 1)

    y_pred_all = regressor.predict(X)
    
    rmse_all = np.sqrt(mean_squared_error(y, y_pred_all))
    
    return [r2_all, adj_r2_all, rmse_all]

# %% [markdown]
# #### Filtering and normalizing numerical targets so they would be on same scale:
#
# Targets which will no be predicte in the below models:
#
# cesdsevmA - severity score, cesdclinmA - binary, psaavmA - avg score per question

# %%
def build_regressors(X, targets):
    """
    Building baseline regressors and saving their coefficients.
    Function can take a list of targets.
    Results and coefficients per model are exported to csv files.
    """

    reg_models = [LinearRegression(),HuberRegressor(alpha=0.01, max_iter=50000), RandomForestRegressor(n_estimators=300, 
                  max_depth=5, min_samples_leaf=2, min_samples_split=4, random_state=0)]

    # Scalers
    scalers = [StandardScaler(), RobustScaler()]

    # Feature selections methods
    reg_selectors = [PCA(), GenericUnivariateSelect(mode='fdr', param=0.5), Lasso(alpha=0.01, max_iter=50000, tol=0.2)]

    # list of results per model
    final_results_reg = []

    # Dataframe saving each model's coefficients
    coefs_df_reg = pd.DataFrame()

    # Cross-Validation object
    kf = KFold(n_splits=10, random_state=0, shuffle=True)

    # Testing each of the models
    with np.errstate(divide='ignore', invalid='ignore'):
        for model in reg_models:

            # Testing each dependent variable
            for target in targets:

                if target == 'DERStotmA':
                    
                    # dropping study ids which have missing DERS scores
                    X = df_feats[(df_feats['study_id'] != 1792) & (df_feats['study_id'] != 1812)]

                X = df_feats.drop(columns=['study_id'])
                y = df_targets[target]

                # Testing each of the scalers
                for scaler in scalers:
                    
                    scores = {'R2(All_X)': [], 'Adj_R2(All_X)': [], 'rmse(All_X)': [], 'K_All_X': [],
                             'Train_R2_CV': [], 'Adj_Train_R2_CV': [], 'Val_R2_CV': [], 'Adj_Val_R2_CV': [],
                             'Train_rmse_CV': [], 'Val_rmse_CV': [], 'K': [], 'target': ''}
                    
                    all_scores = {'PCA': scores, 'FDR': scores, 'Lasso': scores}

                    # cross-validation
                    
                    for ind, (train_index, val_index) in enumerate(kf.split(X, y)):
                        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
                        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

                        # Normalizing
                        
                        scaler.fit(X_train)
                        X_train = scaler.transform(X_train)
                        X_val = scaler.transform(X_val)

                        # Testing each of the feature selection methods
                        
                        for feat_selector in reg_selectors:

                            # Creating new X-sets for each iteration
                            
                            X_train_fresh = X_train
                            X_val_fresh = X_val

                            dict_name = feat_selector.__class__.__name__

                            if dict_name == 'PCA':

                                fs = feat_selector.fit(X_train_fresh)
                                array = np.cumsum(fs.explained_variance_ratio_)

                                # Selecting number of principal components
                                
                                K = np.argmax(array > 0.8)
                                fs = PCA(n_components=K).fit(X_train_fresh)

                                if ind == 0:
                                    
                                    # Calculating metrics on all X Data
                                    
                                    fs_all_pca = PCA().fit(X)
                                    array_all = np.cumsum(fs_all_pca.explained_variance_ratio_)

                                    # Selecting number of principal components
                                    
                                    K_all = np.argmax(array_all > 0.85)
                                    fs_all_pca = PCA(n_components=K_all).fit(X)

                                    X_all_pca = fs_all_pca.transform(X)

                                    reg = model
                                
                                    reg_metrics_all = get_regression_metrics(reg, X_all_pca, y)
                                    
                                    # Getting coefficients of all features

                                    all_coefs_df_pca = coefs_to_df(X, reg, fs_all_pca, scaler, dict_name, K_all, 'PCA')

                                    coefs_df_reg = pd.concat([coefs_df_reg, all_coefs_df_pca], axis=0)

                            elif dict_name == 'Lasso':

                                fs = SelectFromModel(feat_selector)
                                fs.fit(X_train_fresh, y_train)
                                K = sum(fs.get_support())

                                if ind == 0:
                                    
                                    # Calculating metrics on all X Data
                                    
                                    fs_all_lasso = SelectFromModel(feat_selector)
                                    fs_all_lasso.fit(X, y)
                                    X_all_lasso = fs_all_lasso.transform(X)

                                    reg = model
                                    
                                    reg_metrics_all = get_regression_metrics(reg, X_all_lasso, y)
                                    
                                    K_all = sum(fs_all_lasso.get_support())

                                    # Getting coefficients of all features

                                    all_coefs_df_lasso = coefs_to_df(X, reg, fs_all_lasso, scaler, dict_name, K_all)

                                    coefs_df_reg = pd.concat([coefs_df_reg, all_coefs_df_lasso], axis=0)

                            else:

                                dict_name = 'FDR'

                                fs = feat_selector.fit(X_train_fresh, y_train)
                                K = sum(fs.get_support())

                                if ind == 0:
                                    
                                    # Calculating metrics on all X Data
                                    
                                    fs_all_fdr = feat_selector.fit(X, y)
                                    X_all_fdr = fs_all_fdr.transform(X)

                                    reg = model
                                    
                                    reg_metrics_all = get_regression_metrics(reg, X_all_fdr, y)
                                    
                                    K_all = sum(fs_all_fdr.get_support())

                                    # Getting coefficients of all features

                                    all_coefs_df_fdr = coefs_to_df(X, reg, fs_all_fdr, scaler, dict_name, K_all)

                                    coefs_df_reg = pd.concat([coefs_df_reg, all_coefs_df_fdr], axis=0)
                                    
                            
                            # appending metrics of all data to all_scores dictionary
                            if ind == 0:
                                for i, key in enumerate(all_scores[dict_name]):
                                    if i == 3:
                                        break
                                    all_scores[dict_name][key].append(reg_metrics_all[i])
                            all_scores[dict_name]['K_All_X'].append(K_all)

                            X_train_fresh = fs.transform(X_train_fresh)
                            X_val_fresh = fs.transform(X_val_fresh)

                            # Training, predicting and evaluating each model

                            reg = model
                            reg.fit(X_train_fresh, y_train)

                            train_r2 = reg.score(X_train_fresh, y_train)
                            adj_train_r2 = 1 - (1 - train_r2) * (len(y_train) - 1) / (
                                        len(y_train) - X_train_fresh.shape[1] - 1)
                            val_r2 = reg.score(X_val_fresh, y_val)
                            adj_val_r2 = 1 - (1 - val_r2) * (len(y_val) - 1) / (len(y_val) - X_val_fresh.shape[1] - 1)

                            y_pred_train = reg.predict(X_train_fresh)
                            y_pred_val = reg.predict(X_val_fresh)

                            train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
                            val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))

                            # appending metrics of all data to all_scores dictionary
                            if ind == 0:
                                for i, key in enumerate(all_scores[dict_name]):
                                    if i == 3:
                                        break
                                    all_scores[dict_name][key].append(reg_metrics_all[i])
                            all_scores[dict_name]['K_All_X'].append(K_all)

                            # appending metrics of specific fold
                            all_scores[dict_name]['Train_R2_CV'].append(train_r2)
                            all_scores[dict_name]['Adj_Train_R2_CV'].append(adj_train_r2)
                            all_scores[dict_name]['Val_R2_CV'].append(val_r2)
                            all_scores[dict_name]['Adj_Val_R2_CV'].append(adj_val_r2)
                            all_scores[dict_name]['Train_rmse_CV'].append(train_rmse)
                            all_scores[dict_name]['Val_rmse_CV'].append(val_rmse)
                            all_scores[dict_name]['K'].append(K)
                            all_scores[dict_name]['target'] = target

                    # Averaging the scores of each fold
                    
                    for dct, v in all_scores.items():
                        for metric, score in v.items():
                            if metric != 'target':
                                v[metric] = np.mean(score)

                    dicts_keys = ['PCA', 'FDR', 'Lasso']

                    # Saving results and adding to dataframe
                    for dct in dicts_keys:
                        final_results_reg.append({'Model': reg.__class__.__name__,
                                                  'scaler': scaler.__class__.__name__,
                                                  'Feat Selection': dct,
                                                  'Target': all_scores[dct]['target'],
                                                  'Type': 'CV',
                                                  'Num of Features': round(all_scores[dct]['K']),
                                                  'Train_R2_CV': all_scores[dct]['Train_R2_CV'],
                                                  'Adj_Train_R2_CV': all_scores[dct]['Adj_Train_R2_CV'],
                                                  'Val_R2_CV': all_scores[dct]['Val_R2_CV'],
                                                  'Adj_Val_R2_CV': all_scores[dct]['Adj_Val_R2_CV'],
                                                  'Train_RMSE_CV': all_scores[dct]['Train_rmse_CV'],
                                                  'Val_RMSE_CV': all_scores[dct]['Val_rmse_CV']})
                        final_results_reg.append({'Model': reg.__class__.__name__,
                                                  'scaler': scaler.__class__.__name__,
                                                  'Feat Selection': dct,
                                                  'Target': all_scores[dct]['target'],
                                                  'Type': 'All_data',
                                                  'Num of Features': round(all_scores[dct]['K']),
                                                  'R2(All_X)': all_scores[dct]['R2(All_X)'],
                                                  'Adj_R2(All_X)': all_scores[dct]['Adj_R2(All_X)'],
                                                  'rmse(All_X)': all_scores[dct]['rmse(All_X)']})

    final_results_reg_df = pd.DataFrame(final_results_reg).set_index(['Model', 'Target', 'scaler', 'Feat Selection'])

    return final_results_reg_df, coefs_df_reg

# %% [markdown]
# #### Filtering and normalizing numerical targets so they would be on same scale:
#
# Targets which will no be predicte in the below models:
#
# cesdsevmA - severity score, cesdclinmA - binary, psaavmA - avg score per question

# %%
all_targets = ["DERSclrmA", "DERStotmA", "DERSstgmA", "DERSawmA", "DERSimpmA", "DERSgmA", 
               "DERSnamA", "psaavmA", "psatotmA", "cesdtotmA", "cesdclinmA", "cesdsevmA"]

# %%
numeric_targets = set(all_targets) ^ {'cesdsevmA', 'cesdclinmA', 'psaavmA'}

# %%
min_max_scaler = MinMaxScaler()

for target in numeric_targets:
    tmp_arr = np.array(df_targets[target]).reshape(-1,1)
    min_max_scaler.fit(tmp_arr)
    df_targets[target] = min_max_scaler.transform(tmp_arr)

# %% [markdown]
# ### Predicting primary targets:
#
# Primary numeric targets (1 from each of the 3 questionnaires) all have 'totmA' suffix
#
# DERStotmA - score for difficulties in emotion regulation scale
#
# cesdtotmA - score for depression
#
# psatotmA - score for anxiety

# %%
primary_numeric_targets = [x for x in numeric_targets if x.endswith('totmA')]

start_total_runtime = time.time()

final_results_reg_df, coefs_df_reg_primary = build_regressors(df_feats, primary_numeric_targets)
 
end_total_runtime = time.time()

print(f'Total runtime: {round(end_total_runtime - start_total_runtime,5)} seconds\n')
print('psatotmA = Anxiety \nDERStotmA = Difficulties in emotion regulation \ncesdtotmA = Depression')

final_results_reg_df#.style.applymap(_color_red_or_green_reg)
# Out:
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# ...
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# Total runtime: 147.29929 seconds
#
# psatotmA = Anxiety
# DERStotmA = Difficulties in emotion regulation
# cesdtotmA = Depression
#                                                                    Type  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                   CV
#                                                PCA             All_data
#                                                FDR                   CV
#                                                FDR             All_data
#                                                Lasso                 CV
# ...                                                                 ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA             All_data
#                                                FDR                   CV
#                                                FDR             All_data
#                                                Lasso                 CV
#                                                Lasso           All_data
#
#                                                                Num of Features  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                          42
#                                                PCA                          42
#                                                FDR                          42
#                                                FDR                          42
#                                                Lasso                        42
# ...                                                                        ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                          28
#                                                FDR                          28
#                                                FDR                          28
#                                                Lasso                        28
#                                                Lasso                        28
#
#                                                                Train_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                0.698647
#                                                PCA                     NaN
#                                                FDR                0.698647
#                                                FDR                     NaN
#                                                Lasso              0.698647
# ...                                                                    ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                     NaN
#                                                FDR                0.741609
#                                                FDR                     NaN
#                                                Lasso              0.741609
#                                                Lasso                   NaN
#
#                                                                Adj_Train_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                    0.754804
#                                                PCA                         NaN
#                                                FDR                    0.754804
#                                                FDR                         NaN
#                                                Lasso                  0.754804
# ...                                                                        ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                         NaN
#                                                FDR                    1.066072
#                                                FDR                         NaN
#                                                Lasso                  1.066072
#                                                Lasso                       NaN
#
#                                                                Val_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA            -30.609602
#                                                PCA                   NaN
#                                                FDR            -30.609602
#                                                FDR                   NaN
#                                                Lasso          -30.609602
# ...                                                                  ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                   NaN
#                                                FDR             -1.449185
#                                                FDR                   NaN
#                                                Lasso           -1.449185
#                                                Lasso                 NaN
#
#                                                                Adj_Val_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                  4.296596
#                                                PCA                       NaN
#                                                FDR                  4.296596
#                                                FDR                       NaN
#                                                Lasso                4.296596
# ...                                                                      ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                       NaN
#                                                FDR                  1.809373
#                                                FDR                       NaN
#                                                Lasso                1.809373
#                                                Lasso                     NaN
#
#                                                                Train_RMSE_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                  0.109164
#                                                PCA                       NaN
#                                                FDR                  0.109164
#                                                FDR                       NaN
#                                                Lasso                0.109164
# ...                                                                      ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                       NaN
#                                                FDR                  0.114845
#                                                FDR                       NaN
#                                                Lasso                0.114845
#                                                Lasso                     NaN
#
#                                                                Val_RMSE_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                0.899393
#                                                PCA                     NaN
#                                                FDR                0.899393
#                                                FDR                     NaN
#                                                Lasso              0.899393
# ...                                                                    ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                     NaN
#                                                FDR                0.240713
#                                                FDR                     NaN
#                                                Lasso              0.240713
#                                                Lasso                   NaN
#
#                                                                R2(All_X)  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                   NaN
#                                                PCA              0.674397
#                                                FDR                   NaN
#                                                FDR              0.674397
#                                                Lasso                 NaN
# ...                                                                  ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA              0.627811
#                                                FDR                   NaN
#                                                FDR              0.627811
#                                                Lasso                 NaN
#                                                Lasso            0.627811
#
#                                                                Adj_R2(All_X)  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                       NaN
#                                                PCA                  0.667162
#                                                FDR                       NaN
#                                                FDR                  0.667162
#                                                Lasso                     NaN
# ...                                                                      ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                  0.810269
#                                                FDR                       NaN
#                                                FDR                  0.810269
#                                                Lasso                     NaN
#                                                Lasso                0.810269
#
#                                                                rmse(All_X)
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERStotmA StandardScaler PCA                     NaN
#                                                PCA                0.096465
#                                                FDR                     NaN
#                                                FDR                0.096465
#                                                Lasso                   NaN
# ...                                                                    ...
# RandomForestRegressor cesdtotmA RobustScaler   PCA                0.134772
#                                                FDR                     NaN
#                                                FDR                0.134772
#                                                Lasso                   NaN
#                                                Lasso              0.134772
#
# [108 rows x 11 columns]

# %% [markdown]
# #### Saving to CSV

# %%
final_results_reg_df.to_csv('Baseline_Regressors_Results(Primary_Targets-baseline_data).csv')
coefs_df_reg_primary.to_csv('Baseline_Regressors_Coefficients(Primary_Targets-baseline_data).csv')

# %% [markdown]
# ### Predicting secondary targets:

# %%
secondary_numeric_targets = numeric_targets ^ set(primary_numeric_targets)

start_total_runtime = time.time()

final_results_reg_sec_df, coefs_df_reg_sec= build_regressors(df_feats, secondary_numeric_targets)
 
end_total_runtime = time.time()

print(f'Total runtime: {round(end_total_runtime - start_total_runtime,5)} seconds\n')

final_results_reg_sec_df#.style.applymap(_color_red_or_green_reg)
# Out:
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\linear_model\_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# ...
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [140 147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\liorn\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [147 148 149 150 151 152 153 154 155 156 157 158 161 162 164 166 167] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# Total runtime: 364.03933 seconds
#                                                                    Type  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                   CV
#                                                PCA             All_data
#                                                FDR                   CV
#                                                FDR             All_data
#                                                Lasso                 CV
# ...                                                                 ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA             All_data
#                                                FDR                   CV
#                                                FDR             All_data
#                                                Lasso                 CV
#                                                Lasso           All_data
#
#                                                                Num of Features  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                          24
#                                                PCA                          24
#                                                FDR                          24
#                                                FDR                          24
#                                                Lasso                        24
# ...                                                                        ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                          23
#                                                FDR                          23
#                                                FDR                          23
#                                                Lasso                        23
#                                                Lasso                        23
#
#                                                                Train_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                0.484955
#                                                PCA                     NaN
#                                                FDR                0.484955
#                                                FDR                     NaN
#                                                Lasso              0.484955
# ...                                                                    ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                     NaN
#                                                FDR                0.751367
#                                                FDR                     NaN
#                                                Lasso              0.751367
#                                                Lasso                   NaN
#
#                                                                Adj_Train_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                    0.337531
#                                                PCA                         NaN
#                                                FDR                    0.337531
#                                                FDR                         NaN
#                                                Lasso                  0.337531
# ...                                                                        ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                         NaN
#                                                FDR                        -inf
#                                                FDR                         NaN
#                                                Lasso                      -inf
#                                                Lasso                       NaN
#
#                                                                Val_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA            -98.163911
#                                                PCA                   NaN
#                                                FDR            -98.163911
#                                                FDR                   NaN
#                                                Lasso          -98.163911
# ...                                                                  ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                   NaN
#                                                FDR             -0.498765
#                                                FDR                   NaN
#                                                Lasso           -0.498765
#                                                Lasso                 NaN
#
#                                                                Adj_Val_R2_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                      -inf
#                                                PCA                       NaN
#                                                FDR                      -inf
#                                                FDR                       NaN
#                                                Lasso                    -inf
# ...                                                                      ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                       NaN
#                                                FDR                      -inf
#                                                FDR                       NaN
#                                                Lasso                    -inf
#                                                Lasso                     NaN
#
#                                                                Train_RMSE_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                  0.135909
#                                                PCA                       NaN
#                                                FDR                  0.135909
#                                                FDR                       NaN
#                                                Lasso                0.135909
# ...                                                                      ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                       NaN
#                                                FDR                  0.114437
#                                                FDR                       NaN
#                                                Lasso                0.114437
#                                                Lasso                     NaN
#
#                                                                Val_RMSE_CV  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                0.575748
#                                                PCA                     NaN
#                                                FDR                0.575748
#                                                FDR                     NaN
#                                                Lasso              0.575748
# ...                                                                    ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                     NaN
#                                                FDR                0.229244
#                                                FDR                     NaN
#                                                Lasso              0.229244
#                                                Lasso                   NaN
#
#                                                                R2(All_X)  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                   NaN
#                                                PCA              0.394153
#                                                FDR                   NaN
#                                                FDR              0.394153
#                                                Lasso                 NaN
# ...                                                                  ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA              0.685194
#                                                FDR                   NaN
#                                                FDR              0.685194
#                                                Lasso                 NaN
#                                                Lasso            0.685194
#
#                                                                Adj_R2(All_X)  \
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                       NaN
#                                                PCA                  0.337751
#                                                FDR                       NaN
#                                                FDR                  0.337751
#                                                Lasso                     NaN
# ...                                                                      ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                  0.849910
#                                                FDR                       NaN
#                                                FDR                  0.849910
#                                                Lasso                     NaN
#                                                Lasso                0.849910
#
#                                                                rmse(All_X)
# Model                 Target    scaler         Feat Selection
# LinearRegression      DERSgmA   StandardScaler PCA                     NaN
#                                                PCA                0.147705
#                                                FDR                     NaN
#                                                FDR                0.147705
#                                                Lasso                   NaN
# ...                                                                    ...
# RandomForestRegressor DERSclrmA RobustScaler   PCA                0.127687
#                                                FDR                     NaN
#                                                FDR                0.127687
#                                                Lasso                   NaN
#                                                Lasso              0.127687
#
# [216 rows x 11 columns]

# %% [markdown]
# #### Saving to csv:

# %%
final_results_reg_sec_df.to_csv('Baseline_Regressors_Results(Secondary_Targets-baseline_data).csv')
coefs_df_reg_sec.to_csv('Baseline_Regressors_Coefficients(Secondary_Targets-baseline_data).csv')
